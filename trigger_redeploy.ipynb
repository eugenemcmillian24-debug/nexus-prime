# %%
import requests

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"
headers = {"Authorization": f"Bearer {VERCEL_TOKEN}"}

# Get last deployment UID
res = requests.get(f"https://api.vercel.com/v6/deployments?projectId={PROJECT_ID}&limit=1", headers=headers)
data = res.json()
if 'deployments' in data and data['deployments']:
    last_id = data['deployments'][0]['uid']
    print(f"Triggering redeploy for UID: {last_id}")
    redeploy = requests.post(f"https://api.vercel.com/v13/deployments?deploymentId={last_id}", headers=headers)
    if redeploy.status_code == 200:
        print(f"Redeploy successful: {redeploy.json().get('url')}")
    else:
        print(f"Redeploy failed: {redeploy.text}")
else:
    print("No deployments found to redeploy.")
# Out:
# Triggering redeploy for UID: dpl_An5H4LydghwA7BTF2uZjKCUfvVyB
# Redeploy failed: {"error":{"code":"bad_request","message":"Unexpected end of JSON input while parsing near ''"}}
