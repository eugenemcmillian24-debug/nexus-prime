# %%
import requests

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"

headers = {
    "Authorization": f"Bearer {VERCEL_TOKEN}"
}

# Get latest deployment
res = requests.get(f"https://api.vercel.com/v6/deployments?projectId={PROJECT_ID}&limit=1", headers=headers)
deployments = res.json().get('deployments', [])

if deployments:
    latest = deployments[0]
    print(f"Latest Deployment Status: {latest['readyState']}")
    print(f"Deployment URL: https://{latest['url']}")
    if latest['readyState'] == 'ERROR':
        # Get error logs if possible
        print(f"Error details: {latest.get('error')}")
else:
    print("No deployments found.")
# Out:
# Latest Deployment Status: ERROR
# Deployment URL: https://nexus-prime-7sga5ki8c-newordermedia79-9129s-projects.vercel.app
# Error details: None
