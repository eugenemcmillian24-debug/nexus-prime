# %%
import requests
import time

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"
headers = {"Authorization": f"Bearer {VERCEL_TOKEN}"}

# Poll status for 30 seconds
for i in range(3):
    res = requests.get(f"https://api.vercel.com/v6/deployments?projectId={PROJECT_ID}&limit=1", headers=headers)
    latest = res.json()['deployments'][0]
    print(f"Commit: {latest.get('meta', {}).get('githubCommitMessage')}")
    print(f"Status: {latest['readyState']}")
    print(f"URL: https://{latest['url']}")
    if latest['readyState'] in ['READY', 'ERROR']:
        break
    time.sleep(10)
# Out:
# Commit: Fix: Force npm by removing pnpm artifacts and aligning packageManager
# Status: BUILDING
# URL: https://nexus-prime-8cwqybbc7-newordermedia79-9129s-projects.vercel.app
# Commit: Fix: Force npm by removing pnpm artifacts and aligning packageManager
# Status: BUILDING
# URL: https://nexus-prime-8cwqybbc7-newordermedia79-9129s-projects.vercel.app
# Commit: Fix: Force npm by removing pnpm artifacts and aligning packageManager
# Status: BUILDING
# URL: https://nexus-prime-8cwqybbc7-newordermedia79-9129s-projects.vercel.app
