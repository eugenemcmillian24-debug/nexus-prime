# %%
import requests
import json

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
DEPLOY_ID = "dpl_DoHuD6W4fyTsXMnqNzsyQDTurR7P"

headers = {"Authorization": f"Bearer {VERCEL_TOKEN}"}
res = requests.get(f"https://api.vercel.com/v2/deployments/{DEPLOY_ID}/events?direction=backward", headers=headers)

events = res.json()
# Filter for actual build logs
build_logs = [e.get('payload', {}).get('text', e.get('text', '')) for e in events if e.get('type') in ['stdout', 'stderr']]
print("\n".join(build_logs[::-1])) # Print in chronological order
