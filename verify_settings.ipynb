# %%
import requests

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"
headers = {"Authorization": f"Bearer {VERCEL_TOKEN}"}

res = requests.get(f"https://api.vercel.com/v9/projects/{PROJECT_ID}", headers=headers)
settings = res.json()
print(f"Framework: {settings.get('framework')}")
print(f"Root Directory: {settings.get('rootDirectory')}")
print(f"Build Command: {settings.get('buildCommand')}")
print(f"Install Command: {settings.get('installCommand')}")
print(f"Output Directory: {settings.get('outputDirectory')}")
# Out:
# Framework: None
# Root Directory: None
# Build Command: npm run build
# Install Command: npm install
# Output Directory: next
