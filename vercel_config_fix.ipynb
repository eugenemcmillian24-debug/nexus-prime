# %%
import requests

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"

headers = {
    "Authorization": f"Bearer {VERCEL_TOKEN}",
    "Content-Type": "application/json"
}

# Update framework to 'turborepo'
print("Updating project framework to 'turborepo'...")
res = requests.patch(
    f"https://api.vercel.com/v9/projects/{PROJECT_ID}",
    headers=headers,
    json={
        "framework": "turborepo",
        "buildCommand": "turbo build",
        "outputDirectory": ".next" # Turborepo on Vercel usually handles this
    }
)
print(f"Framework update status: {res.status_code}")
# Out:
# Updating project framework to 'turborepo'...
# Framework update status: 400
