# %%
import requests
import time

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"
headers = {"Authorization": f"Bearer {VERCEL_TOKEN}"}

print("Monitoring hardened build sequence...")
for i in range(15):
    res = requests.get(f"https://api.vercel.com/v6/deployments?projectId={PROJECT_ID}&limit=1", headers=headers)
    latest = res.json()['deployments'][0]
    print(f"Status: {latest['readyState']} | Commit: {latest.get('meta', {}).get('githubCommitMessage')[:40]}...")
    if latest['readyState'] in ['READY', 'ERROR']:
        break
    time.sleep(20)

print(f"\nFinal URL: https://{latest['url']}")
if latest['readyState'] == 'READY':
    print("✅ NEXUS PRIME IS LIVE.")
else:
    print("❌ Build still failing. Investigating the final frontier.")
# Out:
# Monitoring hardened build sequence...
# Status: BUILDING | Commit: Fix: Add build-time guards for Supabase ...
# Status: ERROR | Commit: Fix: Add build-time guards for Supabase ...
#
# Final URL: https://nexus-prime-dt11qebzk-newordermedia79-9129s-projects.vercel.app
# ❌ Build still failing. Investigating the final frontier.
