# %%
import requests

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"
headers = {"Authorization": f"Bearer {VERCEL_TOKEN}"}

res = requests.get(f"https://api.vercel.com/v6/deployments?projectId={PROJECT_ID}&limit=1", headers=headers)
deploy_id = res.json()['deployments'][0]['uid']

print(f"Deployment UID: {deploy_id}")
log_res = requests.get(f"https://api.vercel.com/v2/deployments/{deploy_id}/events", headers=headers)
events = log_res.json()

# Look for standard error or explicit build failure messages
for e in events:
    if e.get('type') == 'stderr' or 'error' in e.get('text', '').lower():
        print(f"[{e.get('type')}] {e.get('text')}")
# Out:
# Deployment UID: dpl_QoYbfshaGjHGBW6cBcF15xCowFUm
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
# [stderr] None
