# %%
import requests

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
DEPLOYMENT_ID = "dpl_Cc9xt666rvZshAKVsPhAnNo6v2Zp" # Need to extract the actual ID from previous result or re-query

# Re-query to get the UID
headers = {"Authorization": f"Bearer {VERCEL_TOKEN}"}
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"
res = requests.get(f"https://api.vercel.com/v6/deployments?projectId={PROJECT_ID}&limit=1", headers=headers)
deploy_id = res.json()['deployments'][0]['uid']

print(f"Fetching logs for: {deploy_id}")
# Vercel API for build logs
log_res = requests.get(f"https://api.vercel.com/v2/deployments/{deploy_id}/events", headers=headers)
events = log_res.json()

for event in events:
    if event.get('type') == 'stdout' or event.get('type') == 'stderr':
        print(event.get('text'))
# Out:
# Fetching logs for: dpl_DoHuD6W4fyTsXMnqNzsyQDTurR7P
