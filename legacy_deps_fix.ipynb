# %%
import requests
import time

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"
headers = {
    "Authorization": f"Bearer {VERCEL_TOKEN}",
    "Content-Type": "application/json"
}

# 1. Update settings to use legacy-peer-deps for safety
print("Applying --legacy-peer-deps to bypass version conflicts...")
requests.patch(
    f"https://api.vercel.com/v9/projects/{PROJECT_ID}",
    headers=headers,
    json={
        "installCommand": "npm install --legacy-peer-deps",
        "buildCommand": "npm run build"
    }
)

# 2. Trigger new commit to force a fresh build
# Since I just edited package.json, I will push it.
# Out:
# Applying --legacy-peer-deps to bypass version conflicts...
# <Response [200]>
