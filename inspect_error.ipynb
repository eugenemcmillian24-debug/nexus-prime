# %%
import requests

VERCEL_TOKEN = "vcp_4DKKSk3VWHELULMvuTXC0KXgP50m0JTbbols3QLdbpeP0R3ett3ONFTF"
PROJECT_ID = "prj_Jx94qNzMMYLymbM3ogYNxcmZIuAG"
headers = {"Authorization": f"Bearer {VERCEL_TOKEN}"}

res = requests.get(f"https://api.vercel.com/v6/deployments?projectId={PROJECT_ID}&limit=1", headers=headers)
latest = res.json()['deployments'][0]
uid = latest['uid']

print(f"Fetching detailed data for UID: {uid}")
detail_res = requests.get(f"https://api.vercel.com/v13/deployments/{uid}", headers=headers)
detail = detail_res.json()

print(f"Deployment Status: {detail.get('readyState')}")
if 'error' in detail:
    print(f"Error JSON: {detail['error']}")
else:
    print("No explicit error field in top-level deployment object.")

# Check build logs via different endpoint
log_res = requests.get(f"https://api.vercel.com/v2/deployments/{uid}/events", headers=headers)
events = log_res.json()
print("\nLog Snippets (Tail):")
for e in events[-20:]:
    print(f"[{e.get('type')}] {e.get('text', e.get('payload', ''))}")
# Out:
# Fetching detailed data for UID: dpl_D11m7pqMbT1Mvzz97AGpwbTedyz1
# Deployment Status: ERROR
# No explicit error field in top-level deployment object.
# Log Snippets (Tail):
# [stderr] {'deploymentId': 'dpl_D11m7pqMbT1Mvzz97AGpwbTedyz1', 'info': {'type': 'build', 'name': 'bld_i110yq4sj', 'entrypoint': '.'}, 'text': 'npm error', 'id': '1776143193590396891365300001', 'date': 1776143193590, 'serial': '1776143193590396891365300001'}
# [stderr] {'deploymentId': 'dpl_D11m7pqMbT1Mvzz97AGpwbTedyz1', 'info': {'type': 'build', 'name': 'bld_i110yq4sj', 'entrypoint': '.'}, 'text': 'npm error While resolving: @nexus/web@0.1.0', 'id': '1776143193590396891365300002', 'date': 1776143193590, 'serial': '1776143193590396891365300002'}
# ...
